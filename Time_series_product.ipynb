# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\shrev\Desktop\time_series/perrin-freres-monthly-champagne-.csv")

# %%
df.head()
# Out:
#      Month  Perrin Freres monthly champagne sales millions ?64-?72
# 0  1964-01                                             2815.0
# 1  1964-02                                             2672.0
# 2  1964-03                                             2755.0
# 3  1964-04                                             2721.0
# 4  1964-05                                             2946.0

# %%
df.tail()
# Out:
#                                                  Month  \
# 102                                            1972-07
# 103                                            1972-08
# 104                                            1972-09
# 105                                                NaN
# 106  Perrin Freres monthly champagne sales millions...
#
#      Perrin Freres monthly champagne sales millions ?64-?72
# 102                                             4298.0
# 103                                             1413.0
# 104                                             5877.0
# 105                                                NaN
# 106                                                NaN

# %%
df.shape
# Out:
# (107, 2)

# %%
## Cleaning up the data
df.columns=["Month","Sales"]
df.head()
# Out:
#      Month   Sales
# 0  1964-01  2815.0
# 1  1964-02  2672.0
# 2  1964-03  2755.0
# 3  1964-04  2721.0
# 4  1964-05  2946.0

# %%
## Drop last 2 rows
df.drop(106,axis=0,inplace=True)

# %%
df.tail()
# Out:
#        Month   Sales
# 101  1972-06  5312.0
# 102  1972-07  4298.0
# 103  1972-08  1413.0
# 104  1972-09  5877.0
# 105      NaN     NaN

# %%
df.drop(105,axis=0,inplace=True)

# %%
df.tail()
# Out:
#        Month   Sales
# 100  1972-05  4618.0
# 101  1972-06  5312.0
# 102  1972-07  4298.0
# 103  1972-08  1413.0
# 104  1972-09  5877.0

# %%
# Convert Month into Datetime
df['Month']=pd.to_datetime(df['Month'])

# %%
df.head()
# Out:
#        Month   Sales
# 0 1964-01-01  2815.0
# 1 1964-02-01  2672.0
# 2 1964-03-01  2755.0
# 3 1964-04-01  2721.0
# 4 1964-05-01  2946.0

# %%
df.set_index('Month',inplace=True)

# %%
df.head()
# Out:
#              Sales
# Month
# 1964-01-01  2815.0
# 1964-02-01  2672.0
# 1964-03-01  2755.0
# 1964-04-01  2721.0
# 1964-05-01  2946.0

# %%
df.describe()
# Out:
#               Sales
# count    105.000000
# mean    4761.152381
# std     2553.502601
# min     1413.000000
# 25%     3113.000000
# 50%     4217.000000
# 75%     5221.000000
# max    13916.000000

# %% [markdown]
# ## Step 2: Visualize the Data

# %%
df.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
#looking this graph,we can say this data is seasonal
#(seasonal is all about suppose in each yr in christmas sales goes up) and then down

# %%
# !pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.0-cp310-cp310-win_amd64.whl (9.2 MB)
#      ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/9.2 MB 660.6 kB/s eta 0:00:14
#      ---------------------------------------- 0.1/9.2 MB 1.3 MB/s eta 0:00:07
#      -- ------------------------------------- 0.5/9.2 MB 4.1 MB/s eta 0:00:03
#      -- ------------------------------------- 0.5/9.2 MB 3.8 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.0/9.2 MB 4.6 MB/s eta 0:00:02
#      ----- ---------------------------------- 1
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ---------------------------------------- 0.0/233.8 kB ? eta -:--:--
#      ------------------------------------ - 225.3/233.8 kB 6.7 MB/s eta 0:00:01
#      -------------------------------------- 233.8/233.8 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.3 in c:\users\shrev\desktop\time_series\env\lib\site-packages (from statsmodels) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shrev\desktop\time_series\env\lib\site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shrev\desktop\time_series\env\lib\site-packages (from pandas>=1.0->statsmodels) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\shrev\desktop\time_series\env\lib\site-packages (from pandas>=1.0->statsmodels) (2023.3)
# Requirement already satisfied: six in c:\users\shrev\desktop\time_series\env\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.3 statsmodels-0.14.0

# %%
### Testing For Stationarity

from statsmodels.tsa.stattools import adfuller

# %%
test_result=adfuller(df['Sales'])

# %%
###if Pvalue<0.05 ,we reject Null hypo ie alternate hypo is true,ie data is stationery

# %%
#zip basically combines result,labels
def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(df['Sales'])
# Out:
# ADF Test Statistic : -1.8335930563276204
# p-value : 0.3639157716602462
# #Lags Used : 11
# Number of Observations Used : 93
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %% [markdown]
# ## Differencing

# %%
df
# Out:
#              Sales
# Month
# 1964-01-01  2815.0
# 1964-02-01  2672.0
# 1964-03-01  2755.0
# 1964-04-01  2721.0
# 1964-05-01  2946.0
# ...            ...
# 1972-05-01  4618.0
# 1972-06-01  5312.0
# 1972-07-01  4298.0
# 1972-08-01  1413.0
# 1972-09-01  5877.0
#
# [105 rows x 1 columns]

# %%
df['Sales'].shift(1)
# Out:
# Month
# 1964-01-01       NaN
# 1964-02-01    2815.0
# 1964-03-01    2672.0
# 1964-04-01    2755.0
# 1964-05-01    2721.0
#                ...
# 1972-05-01    4788.0
# 1972-06-01    4618.0
# 1972-07-01    5312.0
# 1972-08-01    4298.0
# 1972-09-01    1413.0
# Name: Sales, Length: 105, dtype: float64

# %%
df['Sales First Difference'] = df['Sales'] - df['Sales'].shift(1)
df['Seasonal First Difference']=df['Sales']-df['Sales'].shift(12)

# %%
df.head(14)
# Out:
#              Sales  Sales First Difference  Seasonal First Difference
# Month
# 1964-01-01  2815.0                     NaN                        NaN
# 1964-02-01  2672.0                  -143.0                        NaN
# 1964-03-01  2755.0                    83.0                        NaN
# 1964-04-01  2721.0                   -34.0                        NaN
# 1964-05-01  2946.0                   225.0                        NaN
# 1964-06-01  3036.0                    90.0                        NaN
# 1964-07-01  2282.0                  -754.0                        NaN
# 1964-08-01  2212.0                   -70.0                        NaN
# 1964-09-01  2922.0                   710.0                        NaN
# 1964-10-01  4301.0                  1379.0                        NaN
# 1964-11-01  5764.0                  1463.0                        NaN
# 1964-12-01  7312.0                  1548.0                        NaN
# 1965-01-01  2541.0                 -4771.0                     -274.0
# 1965-02-01  2475.0                   -66.0                     -197.0

# %%
## Again test dickey fuller test on df['Sales First Difference']
adfuller_test(df['Seasonal First Difference'].dropna())
# Out:
# ADF Test Statistic : -7.626619157213163
# p-value : 2.060579696813685e-11
# #Lags Used : 0
# Number of Observations Used : 92
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
#now our p-value is less than 0.05 which basically says we are rejecting null hypo and accepting alternate hypo
#ie data is stationery
#if p-value is almost 0,then we have a wonderful stationery graph
df['Seasonal First Difference'].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
#Autocorrelation(plot_acf),Partial Autocorrelation(plot_pacf)

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = plot_acf(df['Seasonal First Difference'].iloc[13:],lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = plot_pacf(df['Seasonal First Difference'].iloc[13:],lags=40,ax=ax2)

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
p, d, q = 1, 1, 1
model = ARIMA(df['Sales'], order=(p, d, q))
model_fit = model.fit()
# Out:
# C:\Users\shrev\Desktop\time_series\env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\shrev\Desktop\time_series\env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\shrev\Desktop\time_series\env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Sales   No. Observations:                  105
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -952.814
# Date:                Fri, 13 Oct 2023   AIC                           1911.627
# Time:                        23:41:32   BIC                           1919.560
# Sample:                    01-01-1964   HQIC                          1914.841
#                          - 09-01-1972
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4545      0.114      4.002      0.000       0.232       0.677
# ma.L1         -0.9667      0.056    -17.332      0.000      -1.076      -0.857
# sigma2      5.226e+06   6.17e+05      8.472      0.000    4.02e+06    6.44e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.91   Jarque-Bera (JB):                 2.59
# Prob(Q):                              0.34   Prob(JB):                         0.27
# Heteroskedasticity (H):               3.40   Skew:                             0.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df['forecast']=model_fit.predict(start=90,end=103,dynamic=True)
df[['Sales','forecast']].plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Month'>

# %%
import statsmodels.api as sm

# %%
model=sm.tsa.statespace.SARIMAX(df['Sales'],order=(1, 1, 1),seasonal_order=(1,1,1,12))
results=model.fit()
# Out:
# C:\Users\shrev\Desktop\time_series\env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\shrev\Desktop\time_series\env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
df['forecast']=results.predict(start=90,end=103,dynamic=True)

# %%
#blue line is original data anf orange is a forecasted data
df[['Sales','forecast']].plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Month'>

# %%
### to see how future predictions/projections looks like
from pandas.tseries.offsets import DateOffset

# %%
df.index[-1]
# Out:
# Timestamp('1972-09-01 00:00:00')

# %%
future_dates=[df.index[-1]+ DateOffset(months=x)for x in range(0,24)]

# %%
future_dates
# Out:
# [Timestamp('1972-09-01 00:00:00'),
#  Timestamp('1972-10-01 00:00:00'),
#  Timestamp('1972-11-01 00:00:00'),
#  Timestamp('1972-12-01 00:00:00'),
#  Timestamp('1973-01-01 00:00:00'),
#  Timestamp('1973-02-01 00:00:00'),
#  Timestamp('1973-03-01 00:00:00'),
#  Timestamp('1973-04-01 00:00:00'),
#  Timestamp('1973-05-01 00:00:00'),
#  Timestamp('1973-06-01 00:00:00'),
#  Timestamp('1973-07-01 00:00:00'),
#  Timestamp('1973-08-01 00:00:00'),
#  Timestamp('1973-09-01 00:00:00'),
#  Timestamp('1973-10-01 00:00:00'),
#  Timestamp('1973-11-01 00:00:00'),
#  Timestamp('1973-12-01 00:00:00'),
#  Timestamp('1974-01-01 00:00:00'),
#  Timestamp('1974-02-01 00:00:00'),
#  Timestamp('1974-03-01 00:00:00'),
#  Timestamp('1974-04-01 00:00:00'),
#  Timestamp('1974-05-01 00:00:00'),
#  Timestamp('1974-06-01 00:00:00'),
#  Timestamp('1974-07-01 00:00:00'),
#  Timestamp('1974-08-01 00:00:00')]

# %%
from pandas.tseries.offsets import DateOffset

#creating additional dataset for 24 months,
future_dates=[df.index[-1]+ DateOffset(months=x)for x in range(0,24)]

# %%
future_datset_df=pd.DataFrame(index=future_dates[1:],columns=df.columns)

# %%
future_datset_df.tail()
# Out:
#            Sales Sales First Difference Seasonal First Difference forecast
# 1974-04-01   NaN                    NaN                       NaN      NaN
# 1974-05-01   NaN                    NaN                       NaN      NaN
# 1974-06-01   NaN                    NaN                       NaN      NaN
# 1974-07-01   NaN                    NaN                       NaN      NaN
# 1974-08-01   NaN                    NaN                       NaN      NaN

# %%
future_df=pd.concat([df,future_datset_df])

# %%
#then we can see future predictions
future_df['forecast'] = results.predict(start = 104, end = 120, dynamic= True)  
future_df[['Sales', 'forecast']].plot(figsize=(12, 8)) ;
